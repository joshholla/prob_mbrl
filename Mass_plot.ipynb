# %%
import os
import numpy as np
import glob

# %%
path="/usr/local/data/joshua/experiment_results/"

# %%
for filepath in glob.iglob(path+'*/*/*/'):
    print(filepath)
# Out:
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.656307/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.236826/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.445117/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.547671/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_12_56_33.906494/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.344972/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_18_18_54.732612/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_18_18_54.361501/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_18_18_53.956634/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_21_36_35.611723/
# ...

# %%
for filepath in glob.iglob(path+'*/*/*/'):
    print("python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path "+filepath)
# Out:
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.656307/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.236826/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.445117/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.547671/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_12_56_33.906494/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.344972/
# ...

# %%
path="/usr/local/data/joshua/experiment_results_mm_uniform/"
for filepath in glob.iglob(path+'*/*/*/'):
    print("python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path "+filepath)
    
path="/usr/local/data/joshua/experiment_results_random_initial_state/"
for filepath in glob.iglob(path+'*/*/*/'):
    print("python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path "+filepath)
    
path="/usr/local/data/joshua/experiment_results_no_mm/"
for filepath in glob.iglob(path+'*/*/*/'):
    print("python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path "+filepath)
# Out:
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum/2019_09_07_10_08_34.581384/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum/2019_09_07_05_10_33.861779/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum/2019_09_07_10_08_34.366975/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum/2019_09_07_05_10_34.030797/
# python /localdata/joshua/prob_mbrl/examples/evaluate_policy.py --path /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum/2019_09_07_14_46_21.111112/
# ...

# %%
path="/usr/local/data/joshua/experiment_results/"
for filepath in glob.iglob(path+'*/*/*/'):
    print(filepath)
# Out:
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.656307/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.236826/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.445117/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.547671/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_12_56_33.906494/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.344972/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_18_18_54.732612/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_18_18_54.361501/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_18_18_53.956634/
# /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2/2019_09_04_21_36_35.611723/
# ...

# %%
/Pendulum/2019_09_04_15_48_54.656307

# %%
location="/localdata/joshua/experiment_results/mc_pilco_mm/Pendulum/2019_09_04_15_48_54.656307/args.pth.tar"
torch.load(location)
# Out:
# Namespace(control_H=40, discount_factor=None, dyn_batch_size=100, dyn_components=1, dyn_drop_rate=0.1, dyn_lr=0.0001, dyn_opt_iters=2000, dyn_shape=[200, 200], env='Pendulum', expl_noise=0.0, keep_best=False, learn_reward=False, load_from=None, n_initial_epi=1, num_threads=1, output_folder='/localdata/joshua/experiment_results', plot_level=0, pol_batch_size=100, pol_clip=1.0, pol_drop_rate=0.1, pol_lr=0.001, pol_opt_iters=1000, pol_shape=[200, 200], pred_H=15, ps_iters=100, render=False, seed=14, stop_when_done=False, use_cuda=False)

# %%
/Users/joshuahollla/Desktop/compute/experiment_results_no_mm/mc_pilco_no_mm/Pendulum
/Users/joshuahollla/Desktop/compute/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_16_52_40.213633

# %%
location="/localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_16_52_40.213633/args.pth.tar"
torch.load(location)
# Out:
# Namespace(control_H=40, debug=False, discount_factor=None, dyn_batch_size=100, dyn_components=1, dyn_drop_rate=0.1, dyn_lr=0.0001, dyn_opt_iters=2000, dyn_shape=[200, 200], env='Pendulum', expl_noise=0.0, keep_best=False, learn_reward=False, load_from=None, mm_groups=None, n_initial_epi=1, num_threads=1, output_folder='/localdata/joshua/experiment_results_no_mm', plot_level=0, pol_batch_size=100, pol_clip=1.0, pol_drop_rate=0.1, pol_lr=0.0001, pol_opt_iters=1000, pol_shape=[200, 200], pred_H=25, prioritized_replay=False, ps_iters=100, render=False, seed=42, stop_when_done=False, timesteps_to_sample=None, use_cuda=False)

# %%
I want to plot all the graphs in one place

# %%
path="/localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/"

# %%
for filepath in glob.iglob(path+'*/'):
    print(filepath)
# Out:
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_16_52_40.213633/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_22_34_44.491373/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_16_52_40.299539/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_19_40_23.399972/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_19_40_23.547192/

# %%
for foldername in glob.iglob(path+'*/'):
    print(foldername)
# Out:
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_16_52_40.213633/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_22_34_44.491373/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_16_52_40.299539/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_19_40_23.399972/
# /localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/2019_09_06_19_40_23.547192/

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
for foldername in glob.iglob(path+'*/'):
    trajectories = torch.load(os.path.join(foldername , 'evaluation_trajectories.pth.tar'))
    cumulative = torch.load(os.path.join(foldername , 'evaluation_cumulative.pth.tar'))
    all_rewards = [[np.sum(tr[2]) for tr in evals] for evals in trajectories]
    #fig = plt.figure(figsize=(12,8))
    #_, ax = plt.subplots()
    avg_rewards = [np.average(rew) for rew in all_rewards]
    stdev = [np.std(rew) for rew in all_rewards]
    plt.subplot(cumulative, avg_rewards)
    upper = avg_rewards + (np.divide(stdev,2))
    lower = avg_rewards - (np.divide(stdev,2))
    plt.fill_between(cumulative, upper, lower, interpolate=True, alpha=0.3)
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(left=0.2)
#fig.savefig('{}/all.png'.format(path))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-bf234afbbc8a> in <module>
#       7     avg_rewards = [np.average(rew) for rew in all_rewards]
#       8     stdev = [np.std(rew) for rew in all_rewards]
# ----> 9     plt.subplot(cumulative, avg_rewards)
#      10     upper = avg_rewards + (np.divide(stdev,2))
#      11     lower = avg_rewards - (np.divide(stdev,2))
#
# /usr/local/data/joshua/.miniconda3/envs/mbrl/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# /usr/local/data/joshua/.miniconda3/envs/mbrl/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# ...

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import numpy as np
import glob
import torch

path="/localdata/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum/"

# %%
ax = plt.subplot()
fig = plt.figure(figsize=(12,8))
for foldername in glob.iglob(path+'*/'):
    trajectories = torch.load(os.path.join(foldername , 'evaluation_trajectories.pth.tar'))
    cumulative = torch.load(os.path.join(foldername , 'evaluation_cumulative.pth.tar'))
    all_rewards = [[np.sum(tr[2]) for tr in evals] for evals in trajectories]
    avg_rewards = [np.average(rew) for rew in all_rewards]
    stdev = [np.std(rew) for rew in all_rewards]
    plt.plot(cumulative, avg_rewards)
    upper = avg_rewards + (np.divide(stdev,2))
    lower = avg_rewards - (np.divide(stdev,2))
    plt.fill_between(cumulative, upper, lower, interpolate=True, alpha=0.3)

#fig = plt.figure(figsize=(12,8))
fig.subplots_adjust(bottom=0.2)
fig.subplots_adjust(left=0.2)
fig.savefig('{}/all.png'.format(path))
plt.show()

# %%
path="/usr/local/data/joshua/experiment_results_mm_uniform/"
for filepath in glob.iglob(path+'*/*'):
    print(filepath)
# Out:
# /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum
# /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Humanoid-v2
# /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/HalfCheetah-v2
# /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Cartpole
# /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Ant-v2

# %%
path="/usr/local/data/joshua/"
for filepath in glob.iglob(path+'experiment_*/*/*'):
    print("python /localdata/joshua/prob_mbrl/examples/group_plots.py --path "+filepath)
# Out:
# /usr/local/data/joshua/experiment_results_rerun_vanilla_H25/mc_pilco_mm/Pendulum
# /usr/local/data/joshua/experiment_results_rerun_vanilla_H25/mc_pilco_mm/Cartpole
# /usr/local/data/joshua/experiment_results_random_initial_state/mc_pilco_mm/Pendulum
# /usr/local/data/joshua/experiment_results_random_initial_state/mc_pilco_mm/HalfCheetah-v2
# /usr/local/data/joshua/experiment_results_random_initial_state/mc_pilco_mm/Cartpole
# /usr/local/data/joshua/experiment_results_sanity_Pendulum/mc_pilco_mm/Pendulum
# /usr/local/data/joshua/experiment_results_no_mm/mc_pilco_no_mm/Pendulum
# /usr/local/data/joshua/experiment_results_no_mm/mc_pilco_no_mm/Humanoid-v2
# /usr/local/data/joshua/experiment_results_no_mm/mc_pilco_no_mm/Hopper-v2
# /usr/local/data/joshua/experiment_results_no_mm/mc_pilco_no_mm/HalfCheetah-v2
# /usr/local/data/joshua/experiment_results_no_mm/mc_pilco_no_mm/Cartpole
# /usr/local/data/joshua/experiment_results_no_mm/mc_pilco_no_mm/Ant-v2
# ...

# %%
path="/usr/local/data/joshua/experiment_results/"
for filepath in glob.iglob(path+'*/*'):
    print("python /localdata/joshua/prob_mbrl/examples/group_plots.py --path "+filepath)

path="/usr/local/data/joshua/experiment_results_mm_uniform/"
for filepath in glob.iglob(path+'*/*'):
    print("python /localdata/joshua/prob_mbrl/examples/group_plots.py --path "+filepath)

path="/usr/local/data/joshua/experiment_results_random_initial_state/"
for filepath in glob.iglob(path+'*/*'):
    print("python /localdata/joshua/prob_mbrl/examples/group_plots.py --path "+filepath)
    
path="/usr/local/data/joshua/experiment_results_no_mm/"
for filepath in glob.iglob(path+'*/*'):
    print("python /localdata/joshua/prob_mbrl/examples/group_plots.py --path "+filepath)
# Out:
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/evaluate_policy.py
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Pendulum
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Hopper-v2
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/HalfCheetah-v2
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Cartpole
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results/mc_pilco_mm/Ant-v2
# python /localdata/joshua/prob_mbrl/examples/group_plots.py --path /usr/local/data/joshua/experiment_results_mm_uniform/mc_pilco_mm/Pendulum
# ...
